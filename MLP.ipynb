# %%
from utils.preprocess import get_df, set_data_for_model
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

# %%
data_path = 'data/data.csv'

# %%
df = get_df(data_path)
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = set_data_for_model(df, 42)

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(x='area_mean', y='radius_mean', hue='diagnosis', data=df)
plt.title('Scatterplot of Radius Mean vs Area SE')
plt.show()
